# %%
import pandas as pd
df = pd.read_csv("temp_957342783060187009.csv")

print(df.head())
# Out:
#                                          Description  Job Value  \
# 0                  SEWER LINE REPLACEMENT PIPE BURST        0.0
# 1  DEMO SHED 250SF  IN PREPARATION NEW HOME CONST...        0.0
# 2                                         TEMP POWER        0.0
# 3                                    TEMP POWER POLE        0.0
# 4  SERVICE UPGRADE 200AMPS SAME LOCATION. INSTALL...        0.0
#
#   Record Status Date             Last Updated  Record Status  Longitude  \
# 0           17-12-01  2017-12-01T11:07:39.000  Permit Issued        NaN
# 1           17-12-01  2017-12-01T10:51:26.000      Submitted        NaN
# 2           17-12-01  2017-12-01T12:29:14.000  Permit Issued        NaN
# 3           17-12-01  2017-12-01T10:51:05.000      Submitted        NaN
# 4           17-12-01  2017-12-01T10:34:25.000  Permit Issued        NaN
#
#                  Record Type Record Module  APN  Latitude Date Opened  \
# 0  Project - Building Permit      Building  NaN       NaN    17-12-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14000 entries, 0 to 13999
# Data columns (total 16 columns):
# Description           13884 non-null object
# Job Value             13125 non-null float64
# Record Status Date    14000 non-null object
# Last Updated          14000 non-null object
# Record Status         13979 non-null object
# Longitude             1100 non-null float64
# Record Type           13725 non-null object
# Record Module         14000 non-null object
# APN                   1940 non-null object
# Latitude              1100 non-null float64
# Date Opened           14000 non-null object
# Record ID             14000 non-null object
# Business Name         11288 non-null object
# ID                    14000 non-null int64
# Licence NBR           12127 non-null object
# Address Full Line     13966 non-null object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 1.7+ MB

# %%
df.rename(index=str, columns={"Description": "description", "Job Value": "fee"})
# Out:
#                                              description        fee  \
# 0                      SEWER LINE REPLACEMENT PIPE BURST        0.0
# 1      DEMO SHED 250SF  IN PREPARATION NEW HOME CONST...        0.0
# 2                                             TEMP POWER        0.0
# 3                                        TEMP POWER POLE        0.0
# 4      SERVICE UPGRADE 200AMPS SAME LOCATION. INSTALL...        0.0
# 5      17000-02146: REMOVE INTERIOR SHEAR WALL AT THE...        0.0
# 6      ADD A STATE APPROVED PRE-FAB BATHROOM (204 SF)...    24000.0
# 7      REMOVAL OF 60-FOOT MONO POLE CELL TOWER, FOUND...        0.0
# 8      RESIDENTIAL LEVEL 2 EVSE LOCATED OUTSIDE THE G...        0.0
# 9      RESIDENTIAL FURNACE REPLACEMENT IN THE SAME LO...        0.0
# 10     DEMO RESIDENCE WITH ATTACHED GARAGE 1200SF IN ...        0.0
# 11     INTERIOR 700 SF REMODEL CONVERT BEDROOM TO ART...    80206.0
# 12     RE-ROOF 15 SQUARES TEAR OFF EXISTING AND INSTA...     8190.0
# ...
